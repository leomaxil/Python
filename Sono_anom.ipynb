# %% [markdown]
# Análise de dados da pesquisa do sono.
#
# A pesquisa do sono foi uma pesquisa realizada através da coleta de dados primários com 14 indivíduos ao longo de 28 de janeiro á 26 de fevereiro. O objetivo é identificar possíveis fatores associados com a qualidade do sono, medida através da disposição ao acordar.
# Foi realizado um pré-processamento de dados, onde foi realizada a anonimização dos dados, preservando variáveis identificadoras dos participantes e atribuindo uma letra grega, única para cada um deles. Além da anonimização foram eliminadas as múltiplas respostas no mesmo dia, e criada um score do nível de empenho dos participantes em relação a resposta do questionário ao longo dos dias.

# %%
#Importando bibliotecas 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dados=pd.read_excel("C:/Users/Leo/Google Drive/Python_projects/sono_anonim.xlsx")
dados
# Out:
#        Carimbo de data/hora Hora que dormiu Hora que acordou  \
# 0   2021-01-28 06:19:29.370        23:54:00         05:58:00
# 1   2021-01-28 06:19:30.497        22:25:00         06:00:00
# 2   2021-01-28 06:32:29.040        22:00:00         06:30:00
# 3   2021-01-28 06:43:31.673        22:30:00         04:55:00
# 4   2021-01-28 07:12:09.375        22:00:00         05:30:00
# ..                      ...             ...              ...
# 365 2021-02-26 08:17:59.309        22:30:00         06:55:00
# 366 2021-02-26 09:52:53.679        02:00:00         09:30:00
# 367 2021-02-26 12:03:01.201        03:30:00         12:00:00
# 368 2021-02-26 12:16:51.859        12:30:00         06:30:00
# 369 2021-02-26 12:34:52.952        00:00:00         06:20:00
#
#     Número de vezes que acordou durante o período do sono  \
# 0                                                    1
# 1                                              Nenhuma
# 2                                                    2
# ...
